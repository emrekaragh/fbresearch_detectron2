# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1YjUiMCj6UZWEv8CPP8bQFZdnD4--VmlB/view?usp=sharing"
gdown.download(url, quiet=False, fuzzy=True)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1YjUiMCj6UZWEv8CPP8bQFZdnD4--VmlB
# To: /home/ubuntu/wd/land_segmentation/land_segmentation_coco_dataset.zip
# 100%|██████████████████████████████████████████████████████████████| 973M/973M [00:07<00:00, 135MB/s]
# 'land_segmentation_coco_dataset.zip'

# %%
# !unzip land_segmentation_coco_dataset.zip
# Out:
# Archive:  land_segmentation_coco_dataset.zip
#    creating: land_segmentation_coco_dataset/
#    creating: land_segmentation_coco_dataset/train/
#    creating: land_segmentation_coco_dataset/train/images/
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_1.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_2.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_8.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_13.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_15.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_19.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_30.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_33.jpg
#   inflating: land_segmentation_coco_dataset/train/images/L40B25B4B_crop_34.jpg
# ...
